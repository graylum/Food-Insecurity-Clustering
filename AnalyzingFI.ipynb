# %%
# Render our plots inline
# %matplotlib inline

# warnings: Provides a way to suppress or manage specific warning messages.
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# pandas: Provides data structures and data analysis tools.
import pandas as pd

# numpy: Provides support for working with arrays and mathematical functions on arrays.
import numpy as np

# seaborn: Data visualization library based on matplotlib. 
import seaborn as sns

# matplotlib: A plotting library to produce visualizations.
import matplotlib.pyplot as plt

# StandardScaler: A utility from scikit-learn to standardize features.
from sklearn.preprocessing import StandardScaler

# train_test_split: Utility function from scikit-learn to split datasets.
# GridSearchCV: Utility function from scikit-learn for hyperparameter tuning.
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score

# Various scikit-learn models
from sklearn.linear_model import LinearRegression, SGDClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# xgboost: An optimized gradient boosting library.
import xgboost as xgb
from xgboost import XGBClassifier

# confusion_matrix: A utility function from scikit-learn to create a confusion matrix.
# accuracy_score: A utility function from scikit-learn to calculate accuracy.
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, classification_report

# category_encoders: Provides various encoding schemes to handle categorical variables.
import category_encoders as ce

# Enhance the appearance of plots
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 7)
plt.rcParams['figure.dpi'] = (108)

# %%
df = pd.read_csv('combined_county_datasets_NEW.csv')

# %%
# Show all columns and their data types without truncation
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df.dtypes)
# Out:
# County_State                                                   object
# Population                                                      int64
# Whitepop                                                        int64
# Asianpop                                                        int64
# two_or_more_pop                                                 int64
# Otherpop                                                        int64
# NativePacificIslanderpop                                        int64
# AmericanIndianAlaskanpop                                        int64
# African_American_Blackpop                                       int64
# MedianIncomeHouseholds                                          int64
# MedianIncomeFamilies                                            int64
# MedianIncomeMarried                                             int64
# MedianIncomeNonFamily                                           int64
# percentSnap                                                   float64
# percentNOSnap                                                 float64
# NumberSnap                                                      int64
# NumberNoSnap                                                    int64
# %Employed                                                     float64
# %Unemployed                                                   float64
# NumberEmployed                                                  int64
# NumberUnemployed                                                int64
# eduattain_male_pop_18_24                                        int64
# eduattain_male_pop_18_24_less_high                              int64
# eduattain_male_pop_18_24_high                                   int64
# eduattain_male_pop_18_24_some_college                           int64
# eduattain_male_pop_18_24_bachelors_or_higher                    int64
# eduattain_male_pop_25_34                                        int64
# eduattain_male_pop_25_34_high_or_higher                         int64
# eduattain_male_pop_25_34_bachelors_or_higher                    int64
# eduattain_male_pop_35_44                                        int64
# eduattain_male_pop_35_44_high_or_higher                         int64
# eduattain_male_pop_35_44_bachlors_or_higher                     int64
# eduattain_male_pop_45_64                                        int64
# eduattain_male_pop_45_64_high_or_higher                         int64
# eduattain_male_pop_45_64_bachelors_or_higher                    int64
# eduattain_male_pop_65_plus                                      int64
# eduattain_male_pop_65_plus_high_or_higher                       int64
# eduattain_male_pop_65_plus_bachelors_or_higher                  int64
# eduattain_female_18_24                                          int64
# eduattain_female_18_24_less_high                                int64
# eduattain_female_18_24_high                                     int64
# eduattain_female_18_24_some_college                             int64
# eduattain_female_18_24_bachelors_higher                         int64
# eduattain_female_25_34                                          int64
# eduattain_female_25_34_high_or_higher                           int64
# eduattain_female_25_34_bachelors_or_higher                      int64
# eduattain_female_35_44                                          int64
# eduattain_female_35_44_high_or_higher                           int64
# eduattain_female_35_44_bachelors_or_higher                      int64
# eduattain_female_45_64                                          int64
# eduattain_female_45_64_high_or_higher                           int64
# eduattain_female_45_64_bachelors_or_higher                      int64
# eduattain_female_65_over                                        int64
# eduattain_female_65_over_high_or_higher                         int64
# eduattain_female_65_over_bachelors_or_higher                    int64
# HousingUnits                                                    int64
# PovertyRate                                                   float64
# LAPOP1_10                                                     float64
# LAPOP05_10                                                    float64
# LAPOP1_20                                                     float64
# LALOWI1_10                                                    float64
# LALOWI05_10                                                   float64
# LALOWI1_20                                                    float64
# lapophalf                                                     float64
# lapophalfshare                                                float64
# lalowihalf                                                    float64
# lalowihalfshare                                               float64
# lakidshalf                                                    float64
# lakidshalfshare                                               float64
# laseniorshalf                                                 float64
# laseniorshalfshare                                            float64
# lawhitehalf                                                   float64
# lawhitehalfshare                                              float64
# lablackhalf                                                   float64
# lablackhalfshare                                              float64
# laasianhalf                                                   float64
# laasianhalfshare                                              float64
# lanhopihalf                                                   float64
# lanhopihalfshare                                              float64
# laaianhalf                                                    float64
# laaianhalfshare                                               float64
# laomultirhalf                                                 float64
# laomultirhalfshare                                            float64
# lahisphalf                                                    float64
# lahisphalfshare                                               float64
# lahunvhalf                                                    float64
# lahunvhalfshare                                               float64
# lasnaphalf                                                    float64
# lasnaphalfshare                                               float64
# lapop1                                                        float64
# lapop1share                                                   float64
# lalowi1                                                       float64
# lalowi1share                                                  float64
# lakids1                                                       float64
# lakids1share                                                  float64
# laseniors1                                                    float64
# laseniors1share                                               float64
# lawhite1                                                      float64
# lawhite1share                                                 float64
# lablack1                                                      float64
# lablack1share                                                 float64
# laasian1                                                      float64
# laasian1share                                                 float64
# lanhopi1                                                      float64
# lanhopi1share                                                 float64
# laaian1                                                       float64
# laaian1share                                                  float64
# laomultir1                                                    float64
# laomultir1share                                               float64
# lahisp1                                                       float64
# lahisp1share                                                  float64
# lahunv1                                                       float64
# lahunv1share                                                  float64
# lasnap1                                                       float64
# lasnap1share                                                  float64
# lapop10                                                       float64
# lapop10share                                                  float64
# lalowi10                                                      float64
# lalowi10share                                                 float64
# lakids10                                                      float64
# lakids10share                                                 float64
# laseniors10                                                   float64
# laseniors10share                                              float64
# lawhite10                                                     float64
# lawhite10share                                                float64
# lablack10                                                     float64
# lablack10share                                                float64
# laasian10                                                     float64
# laasian10share                                                float64
# lanhopi10                                                     float64
# lanhopi10share                                                float64
# laaian10                                                      float64
# laaian10share                                                 float64
# laomultir10                                                   float64
# laomultir10share                                              float64
# lahisp10                                                      float64
# lahisp10share                                                 float64
# lahunv10                                                      float64
# lahunv10share                                                 float64
# lasnap10                                                      float64
# lasnap10share                                                 float64
# Overall_Food_Insecurity_Rate                                  float64
# # of Food Insecure Persons Overall                              int64
# Food Insecurity Rate among Black Persons (all ethnicities)    float64
# Food Insecurity Rate among Hispanic Persons (any race)        float64
# Food Insecurity Rate among White, non-Hispanic Persons        float64
# lessthanpercentFILow_Threshold                                float64
# percentFIgreaterthanLowThreshold                              float64
# Child_Food_Insecurity_Rate                                    float64
# # of Food Insecure Children                                     int64
# % food insecure children in HH w/ HH incomes below 185 FPL    float64
# % food insecure children in HH w/ HH incomes above 185 FPL    float64
# Cost_Per_Meal                                                 float64
# Weighted weekly $ needed by FI                                float64
# Weighted Annual Food Budget Shortfall                           int64
# dtype: object

# %%
# Get columns with null values
columns_with_nulls = df.columns[df.isnull().any()]
print(columns_with_nulls) # Visualize
# Out:
# Index(['lapop10', 'lapop10share', 'lalowi10', 'lalowi10share', 'lakids10',
#        'lakids10share', 'laseniors10', 'laseniors10share', 'lawhite10',
#        'lawhite10share', 'lablack10', 'lablack10share', 'laasian10',
#        'laasian10share', 'lanhopi10', 'lanhopi10share', 'laaian10',
#        'laaian10share', 'laomultir10', 'laomultir10share', 'lahisp10',
#        'lahisp10share', 'lahunv10', 'lahunv10share', 'lasnap10',
#        'lasnap10share'],
#       dtype='object')

# %%
df.shape
# Out:
# (41, 155)

# %%
# Check for null values in each column of the DataFrame and filter columns with nulls
null_counts = df.isnull().sum()
columns_with_nulls = null_counts[null_counts > 0]

# Display the names of columns that have null values and their respective count
print(columns_with_nulls)
# Out:
# lapop10             18
# lapop10share        18
# lalowi10            18
# lalowi10share       18
# lakids10            18
# lakids10share       18
# laseniors10         18
# laseniors10share    18
# lawhite10           18
# lawhite10share      18
# lablack10           18
# lablack10share      18
# laasian10           18
# laasian10share      18
# lanhopi10           18
# lanhopi10share      18
# laaian10            18
# laaian10share       18
# laomultir10         18
# laomultir10share    18
# lahisp10            18
# lahisp10share       18
# lahunv10            18
# lahunv10share       18
# lasnap10            18
# lasnap10share       18
# dtype: int64

# %%
# Assuming df is your original DataFrame
df = df.drop(columns=columns_with_nulls.index)

# Now df_cleaned is your DataFrame with the columns having null values dropped

# %%
# Calculate correlation coefficients for selected variables with the overall food insecurity rate
selected_variables = [
    'MedianIncomeHouseholds',
    'MedianIncomeFamilies',
    'MedianIncomeMarried',
    'MedianIncomeNonFamily',
    'NumberSnap',
    'Whitepop',
    'Asianpop',
    'two_or_more_pop',
    'Otherpop',
    'NativePacificIslanderpop',
    'AmericanIndianAlaskanpop',
    'African_American_Blackpop',
    'Overall_Food_Insecurity_Rate'
]
correlation_matrix = df[selected_variables].corr()

# Focus on the correlation of variables with the Overall Food Insecurity Rate
correlation_with_fi = correlation_matrix['Overall_Food_Insecurity_Rate'].sort_values()

# Plotting the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_fi.index, y=correlation_with_fi.values, palette='coolwarm')
plt.xticks(rotation=45, ha='right')
plt.title('Correlation of Selected Variables with Overall Food Insecurity Rate')
plt.ylabel('Correlation Coefficient')
plt.xlabel('Variables')
plt.tight_layout()

correlation_with_fi
# Out:
# MedianIncomeHouseholds         -0.877323
# MedianIncomeFamilies           -0.802482
# MedianIncomeNonFamily          -0.788143
# MedianIncomeMarried            -0.783239
# Whitepop                       -0.483706
# Asianpop                       -0.442491
# Otherpop                       -0.357844
# African_American_Blackpop      -0.351853
# two_or_more_pop                -0.329703
# NumberSnap                     -0.119804
# NativePacificIslanderpop        0.054534
# AmericanIndianAlaskanpop        0.419590
# Overall_Food_Insecurity_Rate    1.000000
# Name: Overall_Food_Insecurity_Rate, dtype: float64

# %%
fig, axs = plt.subplots(2, 4, figsize=(14, 10))

# Scatter plots to visualize the relationship of selected variables with food insecurity rate
variables_to_plot = [
    'MedianIncomeHouseholds',
    'NumberSnap',
    'Whitepop',
    'Asianpop',
    'two_or_more_pop',
    'Otherpop',
    'African_American_Blackpop',
    'two_or_more_pop'
    
]
for ax, variable in zip(axs.flat, variables_to_plot):
    sns.scatterplot(data=df, x=variable, y='Overall_Food_Insecurity_Rate', ax=ax, color='royalblue')
    ax.set_title(f'FI Rate vs. {variable}')
    ax.set_xlabel(variable)
    ax.set_ylabel('Overall Food Insecurity Rate')

plt.tight_layout()
plt.show()

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns

# Set the aesthetic style of the plots
#sns.set(style="whitegrid")

# List of continuous and categorical features
#continuous_features = ['eduattain_male_pop_18_24', 'eduattain_male_pop_18_24_less_high', 
#                       'eduattain_male_pop_18_24_high', 'eduattain_male_pop_18_24_some_college', 'eduattain_male_pop_18_24_bachelors_or_higher']

# Plotting continuous features
#for feature in continuous_features:
#    plt.figure(figsize=(10, 6))
#    sns.histplot(df[feature], kde=True)
#    plt.title(f'Distribution of {feature}')
#    plt.xlabel(feature)
#    plt.ylabel('Frequency')
#    plt.show()

# %%
# Sort the original data by the 'Overall Food Insecurity Rate' in descending order
sorted_original_data = df.sort_values('Overall_Food_Insecurity_Rate', ascending=False)

# Select the top counties with the highest FI rates - let's use top 10 as an example
top_counties_original = sorted_original_data[['County_State', 'Overall_Food_Insecurity_Rate']].head(10)

# %%
# Removing the "North Carolina" part from the 'County_State' entries for cleaner y-axis labels
top_counties_original['County'] = top_counties_original['County_State'].str.replace(', North Carolina', '')

# Plot the horizontal bar chart with modified county names
plt.figure(figsize=(14, 7))
sns.barplot(
    x=top_counties_original['Overall_Food_Insecurity_Rate'],
    y=top_counties_original['County'],
    palette="viridis",
    orient='h'
)
plt.title('Counties with Very High Food Insecurity Rates')
plt.xlabel('Food Insecurity Rate')
plt.ylabel('County')
plt.gca().invert_yaxis()  # To have the highest FI rate at the top of the chart
plt.show()

# %%
# Removing the "North Carolina" part from the 'County_State' entries for all rows
df['County'] = df['County_State'].str.replace(', North Carolina', '')

# Sort the dataframe by the 'Overall Food Insecurity Rate' in descending order for all counties
all_counties_sorted = df.sort_values('Overall_Food_Insecurity_Rate', ascending=False)

# Plot the horizontal bar chart with all county names
plt.figure(figsize=(14, 10))
sns.barplot(
    x=all_counties_sorted['Overall_Food_Insecurity_Rate'],
    y=all_counties_sorted['County'],
    palette="viridis",
    orient='h'
)
plt.title('Food Insecurity Rates by County')
plt.xlabel('Food Insecurity Rate')
plt.ylabel('County')
plt.gca().invert_yaxis()  # To have the highest FI rate at the top of the chart
plt.show()

# %%
# Identifying columns related to Educational Attainment with the prefix "eduattain_"
education_columns = [col for col in df.columns if col.startswith("eduattain_")]

education_columns
# Out:
# ['eduattain_male_pop_18_24',
#  'eduattain_male_pop_18_24_less_high',
#  'eduattain_male_pop_18_24_high',
#  'eduattain_male_pop_18_24_some_college',
#  'eduattain_male_pop_18_24_bachelors_or_higher',
#  'eduattain_male_pop_25_34',
#  'eduattain_male_pop_25_34_high_or_higher',
#  'eduattain_male_pop_25_34_bachelors_or_higher',
#  'eduattain_male_pop_35_44',
#  'eduattain_male_pop_35_44_high_or_higher',
#  'eduattain_male_pop_35_44_bachlors_or_higher',
#  'eduattain_male_pop_45_64',
#  'eduattain_male_pop_45_64_high_or_higher',
#  'eduattain_male_pop_45_64_bachelors_or_higher',
#  'eduattain_male_pop_65_plus',
#  'eduattain_male_pop_65_plus_high_or_higher',
#  'eduattain_male_pop_65_plus_bachelors_or_higher',
#  'eduattain_female_18_24',
#  'eduattain_female_18_24_less_high',
#  'eduattain_female_18_24_high',
#  'eduattain_female_18_24_some_college',
#  'eduattain_female_18_24_bachelors_higher',
#  'eduattain_female_25_34',
#  'eduattain_female_25_34_high_or_higher',
#  'eduattain_female_25_34_bachelors_or_higher',
#  'eduattain_female_35_44',
#  'eduattain_female_35_44_high_or_higher',
#  'eduattain_female_35_44_bachelors_or_higher',
#  'eduattain_female_45_64',
#  'eduattain_female_45_64_high_or_higher',
#  'eduattain_female_45_64_bachelors_or_higher',
#  'eduattain_female_65_over',
#  'eduattain_female_65_over_high_or_higher',
#  'eduattain_female_65_over_bachelors_or_higher']

# %%
# Identifying columns related to Food Insecurity and Educational Attainment
food_insecurity_columns = [col for col in df.columns if "Food Insecurity" in col]
education_columns = [col for col in df.columns if "Education" in col]

(food_insecurity_columns, education_columns)
# Out:
# (['Food Insecurity Rate among Black Persons (all ethnicities)',
#   'Food Insecurity Rate among Hispanic Persons (any race)',
#   'Food Insecurity Rate among White, non-Hispanic Persons '],
#  [])

# %%
# Since we don't have a single "Food Insecurity Rate" for all, let's use one for a broad demographic as a proxy
# reflect the best analytical approach without further context.
food_insecurity_column = 'Overall_Food_Insecurity_Rate'

# Calculating a combined measure for educational attainment (population 25 and older with bachelor's or higher)
# Combining both male and female populations
edu_bachelors_25_plus = df[['eduattain_male_pop_25_34_bachelors_or_higher',
                              'eduattain_male_pop_35_44_bachlors_or_higher', # Note the spelling discrepancy
                              'eduattain_male_pop_45_64_bachelors_or_higher',
                              'eduattain_male_pop_65_plus_bachelors_or_higher',
                              'eduattain_female_25_34_bachelors_or_higher',
                              'eduattain_female_35_44_bachelors_or_higher',
                              'eduattain_female_45_64_bachelors_or_higher',
                              'eduattain_female_65_over_bachelors_or_higher']].sum(axis=1)

population_25_plus = df[['eduattain_male_pop_25_34',
                           'eduattain_male_pop_35_44',
                           'eduattain_male_pop_45_64',
                           'eduattain_male_pop_65_plus',
                           'eduattain_female_25_34',
                           'eduattain_female_35_44',
                           'eduattain_female_45_64',
                           'eduattain_female_65_over']].sum(axis=1)

df['Percentage_25_plus_Bachelors_or_Higher'] = edu_bachelors_25_plus / population_25_plus

# Now, let's calculate the correlation
correlation = df[['Percentage_25_plus_Bachelors_or_Higher', food_insecurity_column]].corr().iloc[0, 1]

correlation
# Out:
# -0.7329999573661244

# %%
import matplotlib.pyplot as plt
import numpy as np

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Percentage_25_plus_Bachelors_or_Higher'], df[food_insecurity_column], alpha=0.5)

# Adding a trend line
z = np.polyfit(df['Percentage_25_plus_Bachelors_or_Higher'], df[food_insecurity_column], 1)
p = np.poly1d(z)
plt.plot(df['Percentage_25_plus_Bachelors_or_Higher'], p(df['Percentage_25_plus_Bachelors_or_Higher']), "r--")

# Labels and title
plt.title('Food Insecurity Rate vs. Educational Attainment')
plt.xlabel('Percentage of Population 25+ with Bachelors or Higher')
plt.ylabel('Food Insecurity Rate among White, non-Hispanic Persons')
plt.grid(True)

plt.show()

# %%
# First, let's extract the relevant column for LALOWI1_10 along with the county names
lalowi_data = df[['County_State', 'LALOWI1_10']].copy()

# Sort the counties by the LALOWI1_10 value
lalowi_data_sorted = lalowi_data.sort_values('LALOWI1_10', ascending=False)

# Now let's create a bar chart
plt.figure(figsize=(15, 10))

# Because there may be many counties, we'll plot just the top 30 for readability
plt.barh(lalowi_data_sorted['County_State'][:30], lalowi_data_sorted['LALOWI1_10'][:30], color='skyblue')

plt.xlabel('Low-access, Low-income Population within 1 mile (Urban) or 10 miles (Rural)')
plt.ylabel('County')
plt.title('Counties with the Highest Low-access, Low-income Populations')
plt.gca().invert_yaxis()  # To display the highest value at the top
plt.show()

# %%
# Attempting a different approach to plot the bar chart to avoid the internal issue
import seaborn as sns

# We'll use seaborn for a potentially more robust plotting
sns.set_theme(style="whitegrid")

# Plotting the top 30 counties for readability, again
plt.figure(figsize=(10, 15))
bar_plot = sns.barplot(x='LALOWI1_10', y='County_State', data=lalowi_data_sorted.head(30),
                       palette='coolwarm', edgecolor='w')

# Adding labels and title
plt.xlabel('Low-access, Low-income Population within 1 mile (Urban) or 10 miles (Rural)')
plt.ylabel('County')
plt.title('Top 30 Counties by Low-access, Low-income Populations (LALOWI1_10)')
plt.show()

# %%
# Calculating the correlation coefficient between LALOWI1_10 and Food Insecurity Rate among White, non-Hispanic Persons

correlation_data = df[['LALOWI1_10', food_insecurity_column]].dropna()

correlation_coefficient = correlation_data.corr().iloc[0, 1]



# Creating the scatter plot to visualize the relationship

plt.figure(figsize=(10, 6))

plt.scatter(correlation_data['LALOWI1_10'], correlation_data[food_insecurity_column], alpha=0.5)



# Adding a trend line

z = np.polyfit(correlation_data['LALOWI1_10'], correlation_data[food_insecurity_column], 1)

p = np.poly1d(z)

plt.plot(correlation_data['LALOWI1_10'], p(correlation_data['LALOWI1_10']), "r--")



# Labels and title

plt.title('NC Food Insecurity Rate vs. Low-access, Low-income Population')

plt.xlabel('Low-access, Low-income Population (LALOWI1_10)')

plt.ylabel('Food Insecurity Rate')

plt.grid(True)



# Show the correlation coefficient on the plot

plt.figtext(0.15, 0.85, f'Correlation coefficient: {correlation_coefficient:.2f}', fontsize=12, va='top', ha='left')



plt.show()



correlation_coefficient
# Out:
# 0.32522288624503654

# %%
# Summing the population counts for each level of education
df['total_male_pop'] = df[['eduattain_male_pop_18_24',
                               'eduattain_male_pop_25_34',
                               'eduattain_male_pop_35_44',
                               'eduattain_male_pop_45_64',
                               'eduattain_male_pop_65_plus']].sum(axis=1)

# Summing the population counts for males with at least a high school diploma
df['total_male_high_or_higher'] = df[['eduattain_male_pop_18_24_high',
                                          'eduattain_male_pop_18_24_some_college',
                                          'eduattain_male_pop_18_24_bachelors_or_higher',
                                          'eduattain_male_pop_25_34_high_or_higher',
                                          'eduattain_male_pop_35_44_high_or_higher',
                                          'eduattain_male_pop_45_64_high_or_higher',
                                          'eduattain_male_pop_65_plus_high_or_higher']].sum(axis=1)

# Calculating the educational attainment rate
df['eduattain_male_rate'] = (df['total_male_high_or_higher'] / df['total_male_pop']) * 100

# %%
# Summing the population counts for each level of education
df['total_female_pop'] = df[['eduattain_female_18_24',
                                 'eduattain_female_25_34',
                                 'eduattain_female_35_44',
                                 'eduattain_female_45_64',
                                 'eduattain_female_65_over']].sum(axis=1)

# Summing the population counts for females with at least a high school diploma
df['total_female_high_or_higher'] = df[['eduattain_female_18_24_high',
                                            'eduattain_female_18_24_some_college',
                                            'eduattain_female_18_24_bachelors_higher',
                                            'eduattain_female_25_34_high_or_higher',
                                            'eduattain_female_35_44_high_or_higher',
                                            'eduattain_female_45_64_high_or_higher',
                                            'eduattain_female_65_over_high_or_higher']].sum(axis=1)

# Calculating the educational attainment rate
df['eduattain_female_rate'] = (df['total_female_high_or_higher'] / df['total_female_pop']) * 100

# %%
# Assuming 'data' is your DataFrame and it includes the necessary columns

# List of columns to include in the correlation matrix
correlation_columns = [
    'Whitepop', 'Asianpop', 'two_or_more_pop', 'Otherpop',
    'NativePacificIslanderpop', 'AmericanIndianAlaskanpop',
    'African_American_Blackpop', 'MedianIncomeHouseholds',
    'MedianIncomeFamilies', 'MedianIncomeMarried', 'MedianIncomeNonFamily',
    'NumberSnap', 'NumberNoSnap', '%Employed', '%Unemployed',
    'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'Cost_Per_Meal',
    'Child_Food_Insecurity_Rate', 'Overall_Food_Insecurity_Rate', 'eduattain_male_rate', 'eduattain_female_rate', 'HousingUnits'
]

# Calculating the correlation matrix
correlation_matrix = df[correlation_columns].corr()

# Increasing the figure size for better readability
plt.figure(figsize=(20, 20))  # You may need to adjust this depending on your screen resolution

# Generating the heatmap without a mask
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f",
            annot_kws={"size": 10})  # Reducing the font size of annotations

# Rotating the x-axis labels to make them readable
plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability

# Rotating the y-axis labels to make them readable
plt.yticks(rotation=0)

# Adding a title with a larger font size
plt.title('Correlation Matrix of Selected Variables', fontsize=20)

# Adjusting the layout
plt.tight_layout()  # This will fit the layout to the figure area

# Showing the plot
plt.show()

# %%
df_clus=df[['Whitepop', 'Asianpop', 'two_or_more_pop', 'Otherpop',
    'NativePacificIslanderpop', 'AmericanIndianAlaskanpop',
    'African_American_Blackpop', 'MedianIncomeHouseholds',
    'MedianIncomeFamilies', 'MedianIncomeMarried', 'MedianIncomeNonFamily',
    'NumberSnap', '%Unemployed',
    'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'Cost_Per_Meal',
    'Overall_Food_Insecurity_Rate', 'eduattain_male_rate', 'HousingUnits', 'County_State']]

# %%
df_clus=df_clus.dropna()

# %%
df_clus2=df_clus.drop('County_State',axis=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_sc = sc.fit_transform(df_clus2)
df_sc = pd.DataFrame(df_sc, columns=df_clus2.columns)

# %%
from sklearn.cluster import KMeans

# %%
distortions = []

for i  in range(1,11):
    km = KMeans(n_clusters=i,
                init='k-means++',
                n_init=10,
                max_iter=300,
                random_state=0)
    km.fit(df_sc)
    distortions.append(km.inertia_)

plt.plot(range(1,11),distortions,marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
model = KMeans(n_clusters=4, random_state=1)
model.fit(df_sc)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
cluster = model.labels_

# %%
df_clus['Cluster']=cluster

# %%
# Display the DataFrame
print(df_clus)
# Out:
#     Whitepop  Asianpop  two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# 0     117967      3008             4252      8432                        72
# 1     122295       940             6092      1977                        15
# 2     230830      3404             4927      3976                        56
# 3      74458      3192             1892      5770                       314
# 4     148373      9020             7603     10784                         0
# 5      72726        99             1920      2830                         0
# 6      62595       593             2020       533                         0
# 7     126059      7190             3505      7927                         0
# 8      57614      1205             2723      5059                         0
# 9      73238      1041              941      1720                         0
# 10     73100      2310             2671       994                        46
# 11    164571      9338            20443     10824                      1310
# 12    144346      2643             1857       638                       127
# 13    171593     14204            10703     10035                       197
# 14    252469      8884             9268      8682                       116
# 15     47610       204             3044      2234                         0
# 16    171404      3455             5024      4361                       452
# 17    288313     27018            18572     15955                       173
# 18     90982      2460             4697      5809                      1039
# 19    107103      1098             2118      2622                         0
# 20    143949      5102             6675      4938                         0
# 21    158143      2028             3710      9769                         0
# 22     78483       753              660       423                        60
# 23    579664     63628            35530     75332                       379
# 24     81646      1454             1600      3150                       175
# 25     46857       170             2700      5506                         0
# 26    189556      2674             7256      4722                       161
# 27    149113      4111            13014      1670                        22
# 28    114580     12048             2898      1600                         9
# 29    100199      2936             6733      8754                       217
# 30    122978      1477             4018      6484                         0
# 31     35102       628             2174      9448                        59
# 32     65035       210             8939      2310                       422
# 33    108730      1196             4985      3714                         0
# 34     58284       383             1347       301                         0
# 35     65624       428             1660      1481                         0
# 36    190315      8031             5843      6391                       208
# 37    718463     83883            27794     45166                       262
# 38     78388      1342             2740      1177                         6
# 39     56425       432             5533      1011                         0
# 40     40482       636             1639      5941                         0
#
#     AmericanIndianAlaskanpop  African_American_Blackpop  \
# 0                       1471                      34307
# 1                        835                      10666
# 2                       1170                      16828
# 3                       1240                       3619
# 4                        162                      40511
# 5                          0                       4603
# 6                        301                       3431
# 7                        716                      14154
# 8                         39                       7830
# 9                        601                      20406
# 10                       704                      22314
# 11                      5130                     123893
# 12                       490                      17508
# 13                       375                     114381
# 14                      1953                     100923
# 15                       230                      16363
# 16                      1008                      38825
# 17                      3141                     184002
# 18                       788                      30201
# 19                       253                       4223
# 20                       317                      20825
# 21                       766                      34923
# 22                       353                       5379
# 15     Franklin County, North Carolina        1
# 16       Gaston County, North Carolina        1
# 17     Guilford County, North Carolina        0
# 18      Harnett County, North Carolina        2
# 19    Henderson County, North Carolina        1
# 20      Iredell County, North Carolina        1
# 21     Johnston County, North Carolina        1
# 22      Lincoln County, North Carolina        1
# 23  Mecklenburg County, North Carolina        3
# 24        Moore County, North Carolina        1
# 25         Nash County, North Carolina        2
# 26  New Hanover County, North Carolina        1
# 27       Onslow County, North Carolina        2
# 28       Orange County, North Carolina        1
# 29         Pitt County, North Carolina        1
# 30     Randolph County, North Carolina        2
# 31      Robeson County, North Carolina        2
# 32   Rockingham County, North Carolina        2
# 33        Rowan County, North Carolina        2
# 34   Rutherford County, North Carolina        2
# 35        Surry County, North Carolina        2
# 36        Union County, North Carolina        1
# 37         Wake County, North Carolina        3
# 38        Wayne County, North Carolina        2
# 39       Wilkes County, North Carolina        2
# 40       Wilson County, North Carolina        2
#
# [41 rows x 22 columns]

# %%
#df_clus.groupby('Cluster').mean().style.bar(axis=0)


df_clus.groupby('Cluster').mean(numeric_only=True).style.bar(axis=0)
# Out:
# <style type="text/css">
# #T_5805b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.9%, transparent 34.9%);
# }
# #T_5805b_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_5805b_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.6%, transparent 61.6%);
# }
# #T_5805b_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.2%, transparent 22.2%);
# }
# #T_5805b_row0_col4, #T_5805b_row0_col12, #T_5805b_row2_col13, #T_5805b_row2_col14, #T_5805b_row2_col15, #T_5805b_row2_col17, #T_5805b_row3_col0, #T_5805b_row3_col1, #T_5805b_row3_col2, #T_5805b_row3_col3, #T_5805b_row3_col5, #T_5805b_row3_col6, #T_5805b_row3_col7, #T_5805b_row3_col8, #T_5805b_row3_col9, #T_5805b_row3_col10, #T_5805b_row3_col11, #T_5805b_row3_col16, #T_5805b_row3_col18, #T_5805b_row3_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_5805b_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.1%, transparent 91.1%);
# }
# #T_5805b_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 52.8%, transparent 52.8%);
# }
# #T_5805b_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.3%, transparent 66.3%);
# }
# #T_5805b_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.9%, transparent 64.9%);
# }
# #T_5805b_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.9%, transparent 68.9%);
# }
# #T_5805b_row0_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.7%, transparent 69.7%);
# }
# #T_5805b_row0_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.3%, transparent 89.3%);
# }
# #T_5805b_row0_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.0%, transparent 87.0%);
# }
# #T_5805b_row0_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.3%, transparent 99.3%);
# }
# #T_5805b_row0_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.0%, transparent 74.0%);
# }
# #T_5805b_row0_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.8%, transparent 88.8%);
# }
# #T_5805b_row0_col17 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.7%, transparent 90.7%);
# }
# #T_5805b_row0_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.3%, transparent 98.3%);
# }
# #T_5805b_row0_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 45.1%, transparent 45.1%);
# }
# #T_5805b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_5805b_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.7%, transparent 5.7%);
# }
# #T_5805b_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.1%, transparent 15.1%);
# }
# #T_5805b_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.3%, transparent 8.3%);
# }
# #T_5805b_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.0%, transparent 12.0%);
# }
# #T_5805b_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.5%, transparent 14.5%);
# }
# #T_5805b_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.6%, transparent 10.6%);
# }
# #T_5805b_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.9%, transparent 81.9%);
# }
# #T_5805b_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.1%, transparent 82.1%);
# }
# #T_5805b_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.9%, transparent 77.9%);
# }
# #T_5805b_row1_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.5%, transparent 71.5%);
# }
# #T_5805b_row1_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.0%, transparent 24.0%);
# }
# #T_5805b_row1_col12, #T_5805b_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_5805b_row1_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 72.7%, transparent 72.7%);
# }
# #T_5805b_row1_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.4%, transparent 75.4%);
# }
# #T_5805b_row1_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.2%, transparent 67.2%);
# }
# #T_5805b_row1_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.7%, transparent 92.7%);
# }
# #T_5805b_row1_col17 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.1%, transparent 78.1%);
# }
# #T_5805b_row1_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.5%, transparent 97.5%);
# }
# #T_5805b_row1_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.4%, transparent 17.4%);
# }
# #T_5805b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.8%, transparent 12.8%);
# }
# #T_5805b_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.2%, transparent 2.2%);
# }
# #T_5805b_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.8%, transparent 11.8%);
# }
# #T_5805b_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.2%, transparent 6.2%);
# }
# #T_5805b_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.8%, transparent 15.8%);
# }
# #T_5805b_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.4%, transparent 80.4%);
# }
# #T_5805b_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.5%, transparent 6.5%);
# }
# #T_5805b_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 63.7%, transparent 63.7%);
# }
# #T_5805b_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.4%, transparent 62.4%);
# }
# #T_5805b_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.5%, transparent 56.5%);
# }
# #T_5805b_row2_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 54.5%, transparent 54.5%);
# }
# #T_5805b_row2_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.4%, transparent 24.4%);
# }
# #T_5805b_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 63.9%, transparent 63.9%);
# }
# #T_5805b_row2_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.5%, transparent 81.5%);
# }
# #T_5805b_row2_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.6%, transparent 91.6%);
# }
# #T_5805b_row2_col19 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.2%, transparent 12.2%);
# }
# #T_5805b_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.2%, transparent 43.2%);
# }
# #T_5805b_row3_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.6%, transparent 47.6%);
# }
# #T_5805b_row3_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.4%, transparent 60.4%);
# }
# #T_5805b_row3_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.0%, transparent 40.0%);
# }
# #T_5805b_row3_col17 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 63.6%, transparent 63.6%);
# }
# </style>
# <table id="T_5805b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5805b_level0_col0" class="col_heading level0 col0" >Whitepop</th>
#       <th id="T_5805b_level0_col1" class="col_heading level0 col1" >Asianpop</th>
#       <th id="T_5805b_level0_col2" class="col_heading level0 col2" >two_or_more_pop</th>
#       <th id="T_5805b_level0_col3" class="col_heading level0 col3" >Otherpop</th>
#       <th id="T_5805b_level0_col4" class="col_heading level0 col4" >NativePacificIslanderpop</th>
#       <th id="T_5805b_level0_col5" class="col_heading level0 col5" >AmericanIndianAlaskanpop</th>
#       <th id="T_5805b_level0_col6" class="col_heading level0 col6" >African_American_Blackpop</th>
#       <th id="T_5805b_level0_col7" class="col_heading level0 col7" >MedianIncomeHouseholds</th>
#       <th id="T_5805b_level0_col8" class="col_heading level0 col8" >MedianIncomeFamilies</th>
#       <th id="T_5805b_level0_co

# %%
# Your list of columns to plot
col = ['Whitepop', 'Asianpop', 'two_or_more_pop', 'Otherpop',
       'NativePacificIslanderpop', 'AmericanIndianAlaskanpop',
       'African_American_Blackpop', 'MedianIncomeHouseholds',
       'MedianIncomeFamilies', 'MedianIncomeMarried', 'MedianIncomeNonFamily',
       'NumberSnap', '%Unemployed',
       'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'Cost_Per_Meal',
       'Overall_Food_Insecurity_Rate', 'eduattain_male_rate', 'HousingUnits']

# Set the figure size larger to accommodate 20 subplots
fig = plt.figure(figsize=(20, 20))

# Loop over the range of columns
for i in range(len(col)):
    # Create a subplot with 5 rows and 4 columns
    plt.subplot(5, 4, i+1)
    plt.title(col[i])
    # Create the boxplot
    sns.boxplot(data=df_clus, y=col[i], x='Cluster')

# Adjust the layout so subplots don't overlap
plt.tight_layout()
plt.show()

# %%
col2 = ['Whitepop', 'Asianpop', 'two_or_more_pop', 'Otherpop',
        'NativePacificIslanderpop', 'AmericanIndianAlaskanpop',
        'African_American_Blackpop', 'MedianIncomeHouseholds',
        'MedianIncomeFamilies', 'MedianIncomeMarried', 'MedianIncomeNonFamily',
        'NumberSnap', '%Unemployed',
        'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'Cost_Per_Meal',
        'Overall_Food_Insecurity_Rate', 'eduattain_male_rate', 'HousingUnits']

# Setting up the figure size to accommodate 20 subplots
fig = plt.figure(figsize=(20, 15))

# Looping over all elements in col2
for i in range(len(col2)):
    # Create a subplot in a 5x4 grid
    plt.subplot(5, 4, i+1)
    # Set the title of the subplot
    plt.title(col2[i])
    # Plot the scatter plot for each column
    sns.scatterplot(data=df_clus, x=col2[i], y='Cost_Per_Meal', hue='Cluster')

# Adjust the layout so subplots don't overlap
plt.tight_layout()
plt.show()

# %%
df_clus[df_clus['Cluster']==0].sort_values('Overall_Food_Insecurity_Rate',ascending=False)
# Out:
#     Whitepop  Asianpop  two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# 11    164571      9338            20443     10824                      1310
# 17    288313     27018            18572     15955                       173
#
#     AmericanIndianAlaskanpop  African_American_Blackpop  \
# 11                      5130                     123893
# 17                      3141                     184002
#
#     MedianIncomeHouseholds  MedianIncomeFamilies  MedianIncomeMarried  ...  \
# 11                   46292                 55078                73799  ...
# 17                   55328                 69273                89607  ...
#
#     %Unemployed  LALOWI1_10  LALOWI05_10  LALOWI1_20  Cost_Per_Meal  \
# 11         0.04      866.38      1533.36      883.76           3.62
# 17         0.03      439.48      1048.47      439.48           3.78
#
#     Overall_Food_Insecurity_Rate  eduattain_male_rate  HousingUnits  \
# 11                         0.141            90.129943        122431
# 17                         0.110            88.146459        196628
#
#                          County_State  Cluster
# 11  Cumberland County, North Carolina        0
# 17    Guilford County, North Carolina        0
#
# [2 rows x 22 columns]

# %%
df_clus[df_clus['Cluster']==1].sort_values('Overall_Food_Insecurity_Rate',ascending=False)
# Out:
#     Whitepop  Asianpop  two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# 29    100199      2936             6733      8754                       217
# 16    171404      3455             5024      4361                       452
# 10     73100      2310             2671       994                        46
# 2     230830      3404             4927      3976                        56
# 6      62595       593             2020       533                         0
# 26    189556      2674             7256      4722                       161
# 14    252469      8884             9268      8682                       116
# 0     117967      3008             4252      8432                        72
#
#     %Unemployed  LALOWI1_10  LALOWI05_10  LALOWI1_20  Cost_Per_Meal  \
# 23         0.02      335.59       782.13      335.59           4.19
# 37         0.02      379.09       788.36      379.09           4.14
#
#     Overall_Food_Insecurity_Rate  eduattain_male_rate  HousingUnits  \
# 23                         0.091            88.600472        362213
# 37                         0.085            92.746692        345645
#
#                           County_State  Cluster
# 23  Mecklenburg County, North Carolina        3
# 37         Wake County, North Carolina        3
#
# [2 rows x 22 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=1)
pca.fit(df_sc)
feature = pca.transform(df_sc)

# %%
df_clus['PCA1']=feature[:,0]
df_clus['PCA2']=feature[:,1]

# %%
#df_clus.groupby('Cluster')['PCA1','PCA2'].mean().T.style.bar(axis=1)

# Updated syntax for selecting multiple columns after a groupby operation
df_clus.groupby('Cluster')[['PCA1', 'PCA2']].mean(numeric_only=True).style.bar(axis=1)
# Out:
# <style type="text/css">
# #T_91987_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.9%, transparent 60.9%);
# }
# #T_91987_row0_col1, #T_91987_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_91987_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 68.3%, #d65f5f 68.3%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_91987_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.3%, transparent 68.3%);
# }
# #T_91987_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.9%, transparent 70.9%);
# }
# #T_91987_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 70.9%, #d65f5f 70.9%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_91987_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.8%, transparent 26.8%);
# }
# </style>
# <table id="T_91987">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91987_level0_col0" class="col_heading level0 col0" >PCA1</th>
#       <th id="T_91987_level0_col1" class="col_heading level0 col1" >PCA2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91987_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91987_row0_col0" class="data row0 col0" >2.271874</td>
#       <td id="T_91987_row0_col1" class="data row0 col1" >3.732271</td>
#     </tr>
#     <tr>
#       <th id="T_91987_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91987_row1_col0" class="data row1 col0" >0.678852</td>
#       <td id="T_91987_row1_col1" class="data row1 col1" >-1.460975</td>
#     </tr>
#     <tr>
#       <th id="T_91987_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91987_row2_col0" class="data row2 col0" >-2.310425</td>
#       <td id="T_91987_row2_col1" class="data row2 col1" >0.946730</td>
#     </tr>
#     <tr>
#       <th id="T_91987_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91987_row3_col0" class="data row3 col0" >10.578219</td>
#       <td id="T_91987_row3_col1" class="data row3 col1" >2.830273</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.DataFrame(pca.components_,columns=df_sc.columns,index=['PCA1','PCA2'])
# Out:
#       Whitepop  Asianpop  two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# PCA1  0.294602  0.291689         0.265058  0.265664                  0.057296
# PCA2  0.159191  0.153517         0.258092  0.204046                  0.250071
#
#       AmericanIndianAlaskanpop  African_American_Blackpop  \
# PCA1                 -0.035503                   0.273093
# PCA2                  0.160583                   0.241951
#
#       MedianIncomeHouseholds  MedianIncomeFamilies  MedianIncomeMarried  \
# PCA1                0.236698              0.235835             0.248039
# PCA2               -0.257990             -0.279611            -0.155288
#
#       MedianIncomeNonFamily  NumberSnap  %Unemployed  LALOWI1_10  LALOWI05_10  \
# PCA1               0.276453    0.215930     0.000629   -0.143156    -0.109422
# PCA2              -0.046695    0.332988     0.254972    0.254419     0.255730
#
#       LALOWI1_20  Cost_Per_Meal  Overall_Food_Insecurity_Rate  \
# PCA1   -0.194206       0.248663                     -0.242401
# PCA2    0.235825      -0.200992                      0.230436
#
#       eduattain_male_rate  HousingUnits
# PCA1             0.192714      0.289893
# PCA2            -0.151866      0.216222

# %%
fig=plt.figure(figsize=(5, 5))
ax = fig.add_subplot()

scatter=ax.scatter(df_clus['PCA1'], df_clus['PCA2'],alpha=0.8, c=cluster)
ax.set_xlabel('principal component 1')
ax.set_ylabel('principal component 2')
plt.legend(handles=scatter.legend_elements()[0], labels=['Cluster0','Cluster1','Cluster2','Cluster3'],
           title="Cluster",loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
df[df['Overall_Food_Insecurity_Rate']>=0.14].sort_values('Overall_Food_Insecurity_Rate', ascending=False).head(3)
# Out:
#                          County_State  Population  Whitepop  Asianpop  \
# 31     Robeson County, North Carolina      130625     35102       628
# 34  Rutherford County, North Carolina       67029     58284       383
# 3        Burke County, North Carolina       90485     74458      3192
#
#     two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# 31             2174      9448                        59
# 34             1347       301                         0
# 3              1892      5770                       314
#
#     AmericanIndianAlaskanpop  African_American_Blackpop  \
# 31                     52786                      30428
# 34                        54                       6660
# 3                       1240                       3619
#
#     MedianIncomeHouseholds  ...  Weighted weekly $ needed by FI  \
# 31                   35035  ...                       18.762397
# 34                   44361  ...                       19.157143
# 3                    47361  ...                       19.061768
#
#     Weighted Annual Food Budget Shortfall             County  \
# 31                               12185000     Robeson County
# 34                                6009000  Rutherford County
# 3                                 7621000       Burke County
#
#     Percentage_25_plus_Bachelors_or_Higher  total_male_pop  \
# 31                                0.148319           46717
# 34                                0.197062           25187
# 3                                 0.185778           36620
#
#     total_male_high_or_higher  eduattain_male_rate  total_female_pop  \
# 31                      35038            75.000535             51867
# 34                      21357            84.793743             28348
# 3                       30232            82.555980             37237
#
#     total_female_high_or_higher  eduattain_female_rate
# 31                        42676              82.279677
# 34                        25326              89.339636
# 3                         30943              83.097457
#
# [3 rows x 137 columns]

# %%
# Calculate the mean for all numerical features within each cluster
cluster_means = df_clus.groupby('Cluster').mean(numeric_only=True) 

# Optionally, calculate other descriptive statistics for these features within each cluster
cluster_medians = df_clus.groupby('Cluster').median(numeric_only=True)
cluster_stddevs = df_clus.groupby('Cluster').std(numeric_only=True)

# Display the calculated profiles for each cluster
print("Cluster Means:")
print(cluster_means)
print("\nCluster Medians:")
print(cluster_medians)
print("\nCluster Standard Deviations:")
print(cluster_stddevs)

# Visualize the mean values of each feature for each cluster using bar plots
# Loop through the columns in cluster_means, which only includes numeric columns
for feature in cluster_means.columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(x=cluster_means.index, y=cluster_means[feature])
    plt.title(f'Mean {feature} by Cluster')
    plt.xlabel('Cluster')
    plt.ylabel(f'Mean {feature}')
    plt.show()
# Out:
# Cluster Means:
#               Whitepop      Asianpop  two_or_more_pop      Otherpop  \
# Cluster
# 0        226442.000000  18178.000000     19507.500000  13389.500000
# 1        130991.200000   4167.550000      4791.000000   4971.800000
# 2         82872.176471   1625.764706      3738.882353   3749.235294
# 3        649063.500000  73755.500000     31662.000000  60249.000000
#
#          NativePacificIslanderpop  AmericanIndianAlaskanpop  \
# Cluster
# 0                           741.5                   4135.50
# 1                            89.2                    658.55
# 2                           117.0                   3650.00
# 3                           320.5                   4537.50
#
#          African_American_Blackpop  MedianIncomeHouseholds  \
# Cluster
# 0                    153947.500000            50810.000000
# 1                     30988.450000            62807.800000
# 2                     18896.823529            48832.117647
# 3                    291470.500000            76643.500000
#
#          MedianIncomeFamilies  MedianIncomeMarried  ...  %Unemployed  \
# Cluster                                             ...
# 0                62175.500000         81703.000000  ...     0.035000
# 1                78627.500000         92431.650000  ...     0.020000
# 2                59826.764706         66994.411765  ...     0.022353
# 3                95827.500000        118663.500000  ...     0.020000
#
#          LALOWI1_10  LALOWI05_10  LALOWI1_20  Cost_Per_Meal  \
# Cluster
# 0        652.930000  1290.915000  661.620000       3.700000
# 1        546.157500   980.118000  600.388000       3.861500
# 2        750.920588  1299.712941  893.895882       3.395882
# 3        357.340000   785.245000  357.340000       4.165000
#
#          Overall_Food_Insecurity_Rate  eduattain_male_rate   HousingUnits  \
# Cluster
# 0                            0.125500            89.138201  159529.500000
# 1                            0.108000            88.367644   61507.450000
# 2                            0.138294            83.033173   43138.411765
# 3                            0.088000            90.673582  353929.000000
#
#               PCA1      PCA2
# Cluster
# 0         2.271874  3.732271
# 1         0.678852 -1.460975
# 2        -2.310425  0.946730
# 3        10.578219  2.830273
#
# [4 rows x 22 columns]
#
# Cluster Medians:
#          Whitepop  Asianpop  two_or_more_pop  Otherpop  \
# Cluster
# 0        226442.0   18178.0          19507.5   13389.5
# 1        120131.0    2805.0           4589.5    4541.5
# 2         73238.0    1041.0           2700.0    2830.0
# 3        649063.5   73755.5          31662.0   60249.0
#
#          NativePacificIslanderpop  AmericanIndianAlaskanpop  \
# Cluster
# 0                           741.5                    4135.5
# 1                            51.0                     551.0
# 2                             0.0                     570.0
# 3                           320.5                    4537.5
#
#          African_American_Blackpop  MedianIncomeHouseholds  \
# Cluster
# 0                         153947.5                 50810.0
# 1                          21569.5                 61541.0
# 2                          17508.0                 49250.0
# 3                         291470.5                 76643.5
#
#          MedianIncomeFamilies  MedianIncomeMarried  ...  %Unemployed  \
# Cluster                                             ...
# 0                     62175.5              81703.0  ...        0.035
# 1                     77399.5              90173.0  ...        0.020
# 2                     60153.0              71565.0  ...        0.020
# 3                     95827.5             118663.5  ...        0.020
#
#          LALOWI1_10  LALOWI05_10  LALOWI1_20  Cost_Per_Meal  \
# Cluster
# 0           652.930     1290.915     661.620          3.700
# 1           564.325      991.835     647.285          3.810
# 2           826.820     1311.150     938.000          3.400
# 3           357.340      785.245     357.340          4.165
#
#          Overall_Food_Insecurity_Rate  eduattain_male_rate  HousingUnits  \
# Cluster
# 0                              0.1255            89.138201      159529.5
# 1                              0.1120            88.464208       60587.5
# 2                              0.1350            84.556688       38693.0
# 3                              0.0880            90.673582      353929.0
#
#               PCA1      PCA2
# Cluster
# 0         2.271874  3.732271
# 1         0.283778 -1.633913
# 2        -2.151638  1.171890
# 3        10.578219  2.830273
#
# [4 rows x 22 columns]
#
# Cluster Standard Deviations:
#              Whitepop      Asianpop  two_or_more_pop      Otherpop  \
# Cluster
# 0        87498.807318  12501.647891      1322.996788   3628.164894
# 1        57926.568383   4070.166562      2696.082226   3393.614059
# 2        35317.512477   1850.409027      3122.083517   2804.156837
# 3        98145.714122  14322.447853      5470.178059  21330.583161
#
#          NativePacificIslanderpop  AmericanIndianAlaskanpop  \
# Cluster
# 0                      803.980410               1406.435388
# 1                      116.681573                482.152463
# 2                      267.350192              12667.369908
# 3                       82.731493               1030.254580
#
#          African_American_Blackpop  MedianIncomeHouseholds  \
# Cluster
# 0                     42503.481510             6389.416875
# 1                     30083.226373             8588.035861
# 2                     13533.906768             6571.793932
# 3                     85621.438814            10707.717988
#
#          MedianIncomeFamilies  MedianIncomeMarried  ...  %Unemployed  \
# Cluster                                             ...
# 0                10037.380759         11177.943997  ...     0.007071
# 1                12631.597947         12374.288702  ...     0.005620
# 2                 9341.255634         13477.903398  ...     0.005623
# 3                12718.729673         11410.582128  ...     0.000000
#
#          LALOWI1_10  LALOWI05_10  LALOWI1_20  Cost_Per_Meal  \
# Cluster
# 0        301.863885   342.869007  314.153401       0.113137
# 1        160.127911   289.543314  167.305880       0.249932
# 2        283.839526   338.907867  303.017305       0.128455
# 3         30.759145     4.405275   30.759145       0.035355
#
#          Overall_Food_Insecurity_Rate  eduattain_male_rate  HousingUnits  \
# Cluster
# 0                            0.021920             1.402535  52465.201844
# 1                            0.013046             2.907082  30424.612669
# 2                            0.015584             4.575420  12091.503381
# 3                            0.004243             2.931820  11715.345151
#
#              PCA1      PCA2
# Cluster
# 0        2.126720  1.945410
# 1        1.168540  1.436099
# 2        0.821650  1.202587
# 3        0.061512  1.457482
#
# [4 rows x 22 columns]

# %%
# Get the PCA components (weights for each feature)
pca_components = pd.DataFrame(pca.components_, columns=df_sc.columns, index=['PCA1', 'PCA2'])

# Display the PCA components
print(pca_components)

# For each principal component, find the features with the largest absolute weights
# We'll display the top 3 for simplicity

# Get the top 3 features for PCA1
top_features_pca1 = pca_components.loc['PCA1'].abs().sort_values(ascending=False).head(3).index.tolist()
# Get the top 3 features for PCA2
top_features_pca2 = pca_components.loc['PCA2'].abs().sort_values(ascending=False).head(3).index.tolist()

print("Top features for PCA1:", top_features_pca1)
print("Top features for PCA2:", top_features_pca2)
# Out:
#       Whitepop  Asianpop  two_or_more_pop  Otherpop  NativePacificIslanderpop  \
# PCA1  0.294602  0.291689         0.265058  0.265664                  0.057296
# PCA2  0.159191  0.153517         0.258092  0.204046                  0.250071
#
#       AmericanIndianAlaskanpop  African_American_Blackpop  \
# PCA1                 -0.035503                   0.273093
# PCA2                  0.160583                   0.241951
#
#       MedianIncomeHouseholds  MedianIncomeFamilies  MedianIncomeMarried  \
# PCA1                0.236698              0.235835             0.248039
# PCA2               -0.257990             -0.279611            -0.155288
#
#       MedianIncomeNonFamily  NumberSnap  %Unemployed  LALOWI1_10  LALOWI05_10  \
# PCA1               0.276453    0.215930     0.000629   -0.143156    -0.109422
# PCA2              -0.046695    0.332988     0.254972    0.254419     0.255730
#
#       LALOWI1_20  Cost_Per_Meal  Overall_Food_Insecurity_Rate  \
# PCA1   -0.194206       0.248663                     -0.242401
# PCA2    0.235825      -0.200992                      0.230436
#
#       eduattain_male_rate  HousingUnits
# PCA1             0.192714      0.289893
# PCA2            -0.151866      0.216222
# Top features for PCA1: ['Whitepop', 'Asianpop', 'HousingUnits']
# Top features for PCA2: ['NumberSnap', 'MedianIncomeFamilies', 'two_or_more_pop']

# %%
features = ['Whitepop', 'Asianpop', 'two_or_more_pop', 'Otherpop',
            'NativePacificIslanderpop', 'AmericanIndianAlaskanpop',
            'African_American_Blackpop', 'MedianIncomeHouseholds',
            'MedianIncomeFamilies', 'MedianIncomeMarried', 'MedianIncomeNonFamily',
            'NumberSnap', '%Unemployed', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20',
            'Cost_Per_Meal', 'Overall_Food_Insecurity_Rate', 'eduattain_male_rate', 
            'HousingUnits', 'County_State']

outlier_results = pd.DataFrame()

for cluster in df_clus['Cluster'].unique():
    print(f"Analyzing outliers for Cluster {cluster}")
    cluster_data = df_clus[df_clus['Cluster'] == cluster]
    outliers = pd.DataFrame()
    
    for feature in features:
        if cluster_data[feature].dtype in ['int64', 'float64']:  # Ensure the feature is numeric
            Q1 = cluster_data[feature].quantile(0.25)
            Q3 = cluster_data[feature].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            
            # Filter outliers within the cluster
            feature_outliers = cluster_data[(cluster_data[feature] < lower_bound) | (cluster_data[feature] > upper_bound)]
            feature_outliers['OutlierFeature'] = feature
            feature_outliers['Cluster'] = cluster
            # Include County Name in the outliers DataFrame
            feature_outliers['CountyName'] = feature_outliers['County_State']
            
            outliers = pd.concat([outliers, feature_outliers], ignore_index=True)
    
    # Print or store the outliers for this particular cluster
    if not outliers.empty:
        print(f"Outliers found for Cluster {cluster}:")
        print(outliers[['CountyName', 'Cluster', 'OutlierFeature'] + features])
        outlier_results = pd.concat([outlier_results, outliers], ignore_index=True)
    else:
        print(f"No significant outliers found for Cluster {cluster}")

# Optionally, save the complete outliers result to a CSV file
# outlier_results.to_csv('cluster_outliers.csv', index=False)
# Out:
# Analyzing outliers for Cluster 1
# Outliers found for Cluster 1:
#                             CountyName  Cluster                OutlierFeature  \
# 0        Durham County, North Carolina        1                      Asianpop
# 1        Gaston County, North Carolina        1      NativePacificIslanderpop
# 2       Forsyth County, North Carolina        1      AmericanIndianAlaskanpop
# 3        Durham County, North Carolina        1     African_American_Blackpop
# 4       Forsyth County, North Carolina        1     African_American_Blackpop
# 5         Union County, North Carolina        1        MedianIncomeHouseholds
# 6        Orange County, North Carolina        1          MedianIncomeFamilies
# 7         Union County, North Carolina        1          MedianIncomeFamilies
# 8        Orange County, North Carolina        1           MedianIncomeMarried
# 9        Durham County, North Carolina        1         MedianIncomeNonFamily
# 10      Forsyth County, North Carolina        1                    NumberSnap
# 11     Cabarrus County, North Carolina        1                   %Unemployed
# 12     Carteret County, North Carolina        1                   %Unemployed
# 13      Chatham County, North Carolina        1                   %Unemployed
# 14      Forsyth County, North Carolina        1                   %Unemployed
# 4          0.02     1024.44      1675.22     1024.44           3.30
# 5          0.02      558.77       977.80      801.22           3.22
# 6          0.02      313.71      1261.80      313.71           3.51
# 7          0.02      313.71      1261.80      313.71           3.51
# 8          0.02      313.71      1261.80      313.71           3.51
# 9          0.02      558.77       977.80      801.22           3.22
# 10         0.03      826.82      1279.27     1115.88           3.27
# 11         0.03     1038.36      1433.87     1221.18           3.39
# 12         0.04      849.07      1279.81      906.29           3.41
# 13         0.02      274.38       658.88      347.17           3.34
# 14         0.02      348.57       515.00      866.50           3.40
# 15         0.02      274.38       658.88      347.17           3.34
# 16         0.02      313.71      1261.80      313.71           3.51
# 17         0.02      558.77       977.80      801.22           3.22
# 18         0.02      981.62      1311.15     1393.00           3.22
# 19         0.02     1228.38      1718.09     1354.16           3.62
# 20         0.02      558.77       977.80      801.22           3.22
#
#     Overall_Food_Insecurity_Rate  eduattain_male_rate  HousingUnits  \
# 0                          0.120            85.657543         60887
# 1                          0.134            92.848360         60092
# 2                          0.150            82.555980         35804
# 3                          0.122            85.446238         41594
# 4                          0.140            81.416808         38693
# 5                          0.180            75.000535         47997
# 6                          0.137            87.630402         31962
# 7                          0.137            87.630402         31962
# 8                          0.137            87.630402         31962
# 9                          0.180            75.000535         47997
# 10                         0.150            82.555980         35804
# 11                         0.135            79.008126         55373
# 12                         0.130            83.612663         47831
# 13                         0.145            78.907298         29914
# 14                         0.149            81.597596         28360
# 15                         0.145            78.907298         29914
# 16                         0.137            87.630402         31962
# 17                         0.180            75.000535         47997
# 18                         0.135            73.784287         33388
# 19                         0.134            92.848360         60092
# 20                         0.180            75.000535         47997
#
#                          County_State
# 0      Catawba County, North Carolina
# 1       Onslow County, North Carolina
# 2        Burke County, North Carolina
# 3      Harnett County, North Carolina
# 4   Rockingham County, North Carolina
# 5      Robeson County, North Carolina
# 6       Wilson County, North Carolina
# 7       Wilson County, North Carolina
# 8       Wilson County, North Carolina
# 9      Robeson County, North Carolina
# 10       Burke County, North Carolina
# 11    Randolph County, North Carolina
# 12       Wayne County, North Carolina
# 13       Surry County, North Carolina
# 14      Wilkes County, North Carolina
# 15       Surry County, North Carolina
# 16      Wilson County, North Carolina
# 17     Robeson County, North Carolina
# 18    Caldwell County, North Carolina
# 19      Onslow County, North Carolina
# 20     Robeson County, North Carolina
#
# [21 rows x 24 columns]
# Analyzing outliers for Cluster 0
# No significant outliers found for Cluster 0
# Analyzing outliers for Cluster 3
# No significant outliers found for Cluster 3
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['OutlierFeature'] = feature
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['Cluster'] = cluster
# C:\Users\malho\AppData\Local\Temp\ipykernel_6840\1302801609.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_outliers['CountyName'] = feature_outliers['County_State']

# %%
# Ensure df_clus only includes numeric columns for this operation
df_numeric = df_clus.select_dtypes(include=[np.number])

# Calculate means and standard deviations for each cluster for all relevant features
cluster_stats = df_numeric.groupby(df_clus['Cluster']).agg(['mean', 'std'])

# Define a function to detect outliers
def is_outlier(value, mean, std, num_std=3):
    """Check if value is an outlier based on mean and std, num_std defines the threshold in terms of standard deviation"""
    if pd.isna(value) or pd.isna(mean) or pd.isna(std):
        return False
    return (value < mean - num_std * std) or (value > mean + num_std * std)

# Add a new column for outlier detection for each feature
for feature in df_numeric.columns:
    df_clus[f'{feature}_outlier'] = df_clus.apply(lambda row: is_outlier(row[feature], cluster_stats.loc[row['Cluster']][feature]['mean'], cluster_stats.loc[row['Cluster']][feature]['std']), axis=1)

# Filter the DataFrame to show only the outliers
outliers = df_clus[df_clus[[f'{feature}_outlier' for feature in df_numeric.columns]].any(axis=1)]

# Display outliers
print(outliers[['County_State', 'Cluster'] + [f'{feature}_outlier' for feature in df_numeric.columns]])

# Optionally, visualize outliers
fig, ax = plt.subplots(figsize=(15, 10))
sns.boxplot(x='Cluster', y='MedianIncomeHouseholds', data=df_clus, ax=ax)
sns.swarmplot(x='Cluster', y='MedianIncomeHouseholds', data=outliers, color='red', ax=ax, label='Outliers')
plt.legend()
plt.show()
# Out:
#                       County_State  Cluster  Whitepop_outlier  \
# 7   Catawba County, North Carolina        2             False
# 16   Gaston County, North Carolina        1             False
# 18  Harnett County, North Carolina        2             False
# 28   Orange County, North Carolina        1             False
# 31  Robeson County, North Carolina        2             False
# 38    Wayne County, North Carolina        2             False
# 40   Wilson County, North Carolina        2             False
#
#     Asianpop_outlier  two_or_more_pop_outlier  Otherpop_outlier  \
# 7               True                    False             False
# 16             False                    False             False
# 18             False                    False             False
# 28             False                    False             False
# 31             False                    False             False
# 38             False                    False             False
# 40             False                    False             False
#
#     NativePacificIslanderpop_outlier  AmericanIndianAlaskanpop_outlier  \
# 7                              False                             False
# 16                              True                             False
# 18                              True                             False
# 28                             False                             False
# 31                             False                              True
# 38                             False                             False
# 40                             False                             False
#
#     African_American_Blackpop_outlier  MedianIncomeHouseholds_outlier  ...  \
# 7                               False                           False  ...
# 16                              False                           False  ...
# 18                              False                           False  ...
# 28                              False                           False  ...
# 31                              False                           False  ...
# 38                              False                           False  ...
# 40                              False                           False  ...
#
#     LALOWI1_10_outlier  LALOWI05_10_outlier  LALOWI1_20_outlier  \
# 7                False                False               False
# 16               False                False               False
# 18               False                False               False
# 28               False                False               False
# 31               False                False               False
# 38               False                False               False
# 40               False                False               False
#
#     Cost_Per_Meal_outlier  Overall_Food_Insecurity_Rate_outlier  \
# 7                   False                                 False
# 16                  False                                 False
# 18                  False                                 False
# 28                  False                                 False
# 31                  False                                 False
# 38                  False                                 False
# 40                  False                                 False
#
#     eduattain_male_rate_outlier  HousingUnits_outlier  Cluster_outlier  \
# 7                         False                 False            False
# 16                        False                 False            False
# 18                        False                 False            False
# 28                        False                 False            False
# 31                        False                 False            False
# 38                        False                 False            False
# 40                        False                 False            False
#
#     PCA1_outlier  PCA2_outlier
# 7          False         False
# 16         False         False
# 18         False         False
# 28         False         False
# 31         False         False
# 38         False         False
# 40         False         False
#
# [7 rows x 25 columns]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'df' is your DataFrame and it's already loaded

# Define your features and target variable
y1 = df_clus['Overall_Food_Insecurity_Rate']
X1 = df_clus.drop(['County_State'], axis=1)


# Split the data into 70% training and 30% testing
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.3, random_state=42)

# Initialize a standard scaler and scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train1)
X_scaled_test = scaler.transform(X_test1)

# Define hyperparameters for Random Forest
param_grid_rf = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Set up the grid search for Random Forest
grid_search_rf = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid_rf,
                              cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')
grid_search_rf.fit(X_scaled, y_train1)

# Initialize and train the XGBoost Regressor
xgb_model = xgb.XGBRegressor()
xgb_model.fit(X_scaled, y_train1)

# Define a dictionary of regression algorithms
regressors = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regressor': DecisionTreeRegressor(),
    'Random Forest Regressor': grid_search_rf.best_estimator_,
    'Support Vector Regressor': SVR(),
    'K-Nearest Neighbors Regressor': KNeighborsRegressor(),
    'XGBoost': xgb_model
}

# Dictionary to store results
results = {}

# Loop through each regression algorithm and store results
for name, reg in regressors.items():
    reg.fit(X_scaled, y_train1)
    y_pred = reg.predict(X_scaled_test)
    mse = mean_squared_error(y_test1, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test1, y_pred)
    r_squared = r2_score(y_test1, y_pred)
    results[name] = {
        'Mean Squared Error (MSE)': mse,
        'Root Mean Squared Error (RMSE)': rmse,
        'Mean Absolute Error (MAE)': mae,
        'R-squared (R2)': r_squared
    }

# Print results for each regression algorithm
for name, metrics in results.items():
    print(f"Regressor: {name}")
    print(f"Mean Squared Error (MSE): {metrics['Mean Squared Error (MSE)']:.2f}")
    print(f"Root Mean Squared Error (RMSE): {metrics['Root Mean Squared Error (RMSE)']:.2f}")
    print(f"Mean Absolute Error (MAE): {metrics['Mean Absolute Error (MAE)']:.2f}")
    print(f"R-squared (R2): {metrics['R-squared (R2)']:.2f}")
    print("=" * 40)

# Check Feature Importance using Random Forest
importances = grid_search_rf.best_estimator_.feature_importances_
features = X1.columns  # This is the corrected line for features

# ------------------------------------------

#Plotting features of importance
plt.figure(figsize=(12,6))
indices = np.argsort(importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# Regressor: Linear Regression
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.00
# Mean Absolute Error (MAE): 0.00
# R-squared (R2): 1.00
# ========================================
# Regressor: Decision Tree Regressor
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.01
# Mean Absolute Error (MAE): 0.01
# R-squared (R2): 0.40
# ========================================
# Regressor: Random Forest Regressor
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.00
# Mean Absolute Error (MAE): 0.00
# R-squared (R2): 0.93
# ========================================
# Regressor: Support Vector Regressor
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.02
# Mean Absolute Error (MAE): 0.02
# R-squared (R2): -0.57
# ========================================
# Regressor: K-Nearest Neighbors Regressor
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.01
# Mean Absolute Error (MAE): 0.01
# R-squared (R2): 0.68
# ========================================
# Regressor: XGBoost
# Mean Squared Error (MSE): 0.00
# Root Mean Squared Error (RMSE): 0.01
# Mean Absolute Error (MAE): 0.01
# R-squared (R2): 0.30
# ========================================
